# %% [markdown]
# <a href="https://colab.research.google.com/github/raffiainuls/Tugasbesar/blob/main/Tugas_PM_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np                                
import matplotlib.pyplot as plt
from keras.utils import np_utils
import keras as k
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras import utils as np_utils
from keras.regularizers import l2
import h5py
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
import numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten

from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from keras.preprocessing import image
from keras.utils import np_utils
## --------------------------------------------
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, MaxPool2D, Flatten, GlobalMaxPooling2D, AveragePooling2D, GlobalMaxPooling2D, BatchNormalization, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# %%
#load data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
img_rows, img_cols , channels= 32,32,3
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i])
plt.show()

# %%
# set up image augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
    #zoom_range=0.3
    )
datagen.fit(x_train)

# %%
# see example augmentation images
for X_batch, y_batch in datagen.flow(x_train, y_train, batch_size=9):
    for i in range(0, 9):
        plt.subplot(330 + 1 + i)
        plt.imshow(X_batch[i].astype(np.uint8))
    plt.show()
    break

# %%
#reshape into images
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)
input_shape = (img_rows, img_cols, 1)
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
x_train=x_train.astype("float32")  
x_test=x_test.astype("float32")
mean=np.mean(x_train)
std=np.std(x_train)
x_test=(x_test-mean)/std
x_train=(x_train-mean)/std

# %%
# labels
num_classes=10
y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)

# %%
# plotting helper function
def plothist(hist):
    plt.plot(hist.history['acc'])
    plt.plot(hist.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
reg=None
num_filters=32
ac='relu'
adm=Adam(lr=0.001,decay=0, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
opt=adm
drop_dense=0.5
drop_conv=0

model = Sequential()

model.add(Conv2D(num_filters, (3, 3), activation=ac, kernel_regularizer=reg, input_shape=(img_rows, img_cols, channels),padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Conv2D(num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(MaxPooling2D(pool_size=(2, 2)))   # reduces to 16x16x3xnum_filters
model.add(Dropout(drop_conv))

model.add(Conv2D(2*num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Conv2D(2*num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(MaxPooling2D(pool_size=(2, 2)))   # reduces to 8x8x3x(2*num_filters)
model.add(Dropout(drop_conv))

model.add(Conv2D(4*num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Conv2D(4*num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(MaxPooling2D(pool_size=(2, 2)))   # reduces to 4x4x3x(4*num_filters)
model.add(Dropout(drop_conv))

model.add(Flatten())
model.add(Dense(512, activation=ac,kernel_regularizer=reg))
model.add(BatchNormalization())
model.add(Dropout(drop_dense))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,345,066
# Trainable params: 1,343,146
# Non-trainable params: 1,920
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer=opt)

# %%
# training without augmentation
history=model.fit(x_train, y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 391/391 [==============================] - 46s 39ms/step - loss: 1.4577 - accuracy: 0.5192 - val_loss: 1.1797 - val_accuracy: 0.5905
# Epoch 2/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.8524 - accuracy: 0.7009 - val_loss: 0.7647 - val_accuracy: 0.7319
# Epoch 3/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.6710 - accuracy: 0.7649 - val_loss: 0.6919 - val_accuracy: 0.7588
# Epoch 4/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.5574 - accuracy: 0.8052 - val_loss: 0.7196 - val_accuracy: 0.7658
# Epoch 5/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.4674 - accuracy: 0.8384 - val_loss: 0.6571 - val_accuracy: 0.7836
# Epoch 6/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.3933 - accuracy: 0.8625 - val_loss: 0.6584 - val_accuracy: 0.7898
# Epoch 7/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.3261 - accuracy: 0.8855 - val_loss: 0.6502 - val_accuracy: 0.7967
# Epoch 8/100
# 391/391 [==============================] - 15s 38ms/step - loss: 0.2642 - accuracy: 0.9064 - val_loss: 0.7265 - val_accuracy: 0.7887
# Epoch 9/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.2140 - accuracy: 0.9230 - val_loss: 0.7452 - val_accuracy: 0.7948
# Epoch 10/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.1818 - accuracy: 0.9366 - val_loss: 0.8235 - val_accuracy: 0.7834
# Epoch 11/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.1626 - accuracy: 0.9422 - val_loss: 0.8311 - val_accuracy: 0.7885
# Epoch 12/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.1359 - accuracy: 0.9517 - val_loss: 0.8301 - val_accuracy: 0.7939
# Epoch 13/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.1172 - accuracy: 0.9591 - val_loss: 0.8273 - val_accuracy: 0.7982
# Epoch 14/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.1019 - accuracy: 0.9643 - val_loss: 0.9167 - val_accuracy: 0.7949
# Epoch 15/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0963 - accuracy: 0.9667 - val_loss: 0.9298 - val_accuracy: 0.7929
# Epoch 16/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0892 - accuracy: 0.9691 - val_loss: 0.9307 - val_accuracy: 0.7935
# Epoch 17/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0908 - accuracy: 0.9675 - val_loss: 0.9154 - val_accuracy: 0.8043
# Epoch 18/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0836 - accuracy: 0.9710 - val_loss: 0.9670 - val_accuracy: 0.7966
# Epoch 19/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0741 - accuracy: 0.9739 - val_loss: 0.9558 - val_accuracy: 0.8049
# Epoch 20/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0672 - accuracy: 0.9765 - val_loss: 1.0030 - val_accuracy: 0.8016
# Epoch 21/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0712 - accuracy: 0.9756 - val_loss: 0.9740 - val_accuracy: 0.7986
# Epoch 22/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0684 - accuracy: 0.9760 - val_loss: 1.0756 - val_accuracy: 0.7940
# Epoch 23/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0587 - accuracy: 0.9799 - val_loss: 1.0431 - val_accuracy: 0.8017
# Epoch 24/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0661 - accuracy: 0.9769 - val_loss: 1.0383 - val_accuracy: 0.7975
# Epoch 25/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0537 - accuracy: 0.9807 - val_loss: 1.1102 - val_accuracy: 0.7951
# Epoch 26/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0526 - accuracy: 0.9819 - val_loss: 1.0573 - val_accuracy: 0.8106
# Epoch 27/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0610 - accuracy: 0.9790 - val_loss: 1.0051 - val_accuracy: 0.8119
# Epoch 28/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0433 - accuracy: 0.9855 - val_loss: 0.9975 - val_accuracy: 0.8187
# Epoch 29/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0468 - accuracy: 0.9836 - val_loss: 1.0421 - val_accuracy: 0.8139
# Epoch 30/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0468 - accuracy: 0.9840 - val_loss: 1.1070 - val_accuracy: 0.8104
# Epoch 31/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0462 - accuracy: 0.9846 - val_loss: 1.0101 - val_accuracy: 0.8103
# Epoch 32/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0497 - accuracy: 0.9836 - val_loss: 1.0914 - val_accuracy: 0.8115
# Epoch 33/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0538 - accuracy: 0.9814 - val_loss: 1.0234 - val_accuracy: 0.8142
# Epoch 34/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0354 - accuracy: 0.9880 - val_loss: 1.0136 - val_accuracy: 0.8175
# Epoch 35/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0355 - accuracy: 0.9875 - val_loss: 1.0809 - val_accuracy: 0.8166
# Epoch 36/100
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0376 - accuracy: 0.9868 - val_loss: 1.1319 - val_accuracy: 0.8075
# Epoch 37/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0361 - accuracy: 0.9877 - val_loss: 1.1524 - val_accuracy: 0.8065
# Epoch 38/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0381 - accuracy: 0.9865 - val_loss: 1.1392 - val_accuracy: 0.8138
# Epoch 39/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0366 - accuracy: 0.9871 - val_loss: 1.1008 - val_accuracy: 0.8141
# Epoch 40/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0383 - accuracy: 0.9870 - val_loss: 1.0993 - val_accuracy: 0.8158
# Epoch 41/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0366 - accuracy: 0.9875 - val_loss: 1.1367 - val_accuracy: 0.8159
# Epoch 42/100
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0355 - accuracy: 0.9882 - val_loss: 1.1299 - val_accuracy: 0.8094
# Epoch 43/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0354 - accuracy: 0.9874 - val_loss: 1.1503 - val_accuracy: 0.8144
# Epoch 44/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0322 - accuracy: 0.9892 - val_loss: 1.1840 - val_accuracy: 0.8054
# Epoch 45/100
# 391/391 [==============================] - 14s 36ms/step - loss: 0.0284 - accuracy: 0.9899 - val_loss: 1.1588 - val_accuracy: 0.8090
# Epoch 46/100
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0301 - accuracy: 0.9898 - val_loss: 1.1558 - val_accuracy: 0.8092
# Epoch 47/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0252 - accuracy: 0.9915 - val_loss: 1.1494 - val_accuracy: 0.8161
# Epoch 48/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0304 - accuracy: 0.9900 - val_loss: 1.2287 - val_accuracy: 0.8056
# Epoch 49/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0368 - accuracy: 0.9874 - val_loss: 1.2300 - val_accuracy: 0.8135
# Epoch 50/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0291 - accuracy: 0.9896 - val_loss: 1.1671 - val_accuracy: 0.8181
# Epoch 51/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0265 - accuracy: 0.9906 - val_loss: 1.2071 - val_accuracy: 0.8167
# Epoch 52/100
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0270 - accuracy: 0.9907 - val_loss: 1.2177 - val_accuracy: 0.8105
# Epoch 53/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0289 - accuracy: 0.9902 - val_loss: 1.1432 - val_accuracy: 0.8174
# Epoch 54/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0236 - accuracy: 0.9917 - val_loss: 1.1525 - val_accuracy: 0.8181
# Epoch 55/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 1.2267 - val_accuracy: 0.8104
# Epoch 56/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0323 - accuracy: 0.9893 - val_loss: 1.2130 - val_accuracy: 0.8156
# Epoch 57/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0239 - accuracy: 0.9917 - val_loss: 1.2156 - val_accuracy: 0.8132
# Epoch 58/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0233 - accuracy: 0.9924 - val_loss: 1.2111 - val_accuracy: 0.8144
# Epoch 59/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0212 - accuracy: 0.9928 - val_loss: 1.1686 - val_accuracy: 0.8185
# Epoch 60/100
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0269 - accuracy: 0.9909 - val_loss: 1.1752 - val_accuracy: 0.8188
# Epoch 61/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0210 - accuracy: 0.9927 - val_loss: 1.2108 - val_accuracy: 0.8167
# Epoch 62/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0245 - accuracy: 0.9917 - val_loss: 1.2161 - val_accuracy: 0.8184
# Epoch 63/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0204 - accuracy: 0.9928 - val_loss: 1.2523 - val_accuracy: 0.8184
# Epoch 64/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0170 - accuracy: 0.9943 - val_loss: 1.2035 - val_accuracy: 0.8179
# Epoch 65/100
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 1.2727 - val_accuracy: 0.8109
# Epoch 66/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0268 - accuracy: 0.9911 - val_loss: 1.3451 - val_accuracy: 0.8065
# Epoch 67/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0240 - accuracy: 0.9921 - val_loss: 1.2261 - val_accuracy: 0.8119
# Epoch 68/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0216 - accuracy: 0.9929 - val_loss: 1.2391 - val_accuracy: 0.8130
# Epoch 69/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0207 - accuracy: 0.9929 - val_loss: 1.2253 - val_accuracy: 0.8228
# Epoch 70/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0157 - accuracy: 0.9948 - val_loss: 1.2494 - val_accuracy: 0.8182
# Epoch 71/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0176 - accuracy: 0.9938 - val_loss: 1.2608 - val_accuracy: 0.8166
# Epoch 72/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0203 - accuracy: 0.9929 - val_loss: 1.2667 - val_accuracy: 0.8128
# Epoch 73/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0170 - accuracy: 0.9943 - val_loss: 1.2762 - val_accuracy: 0.8129
# Epoch 74/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 1.2560 - val_accuracy: 0.8150
# Epoch 75/100
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0209 - accuracy: 0.9929 - val_loss: 1.3133 - val_accuracy: 0.8113
# Epoch 76/100
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0198 - accuracy: 0.9929 - val_loss: 1.2958 - val_accuracy: 0.8199
# Epoch 77/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0186 - accuracy: 0.9935 - val_loss: 1.2851 - val_accuracy: 0.8143
# Epoch 78/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0197 - accuracy: 0.9933 - val_loss: 1.2499 - val_accuracy: 0.8206
# Epoch 79/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 1.3039 - val_accuracy: 0.8131
# Epoch 80/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0149 - accuracy: 0.9947 - val_loss: 1.3068 - val_accuracy: 0.8170
# Epoch 81/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0182 - accuracy: 0.9938 - val_loss: 1.2840 - val_accuracy: 0.8136
# Epoch 82/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0192 - accuracy: 0.9933 - val_loss: 1.3221 - val_accuracy: 0.8149
# Epoch 83/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0178 - accuracy: 0.9935 - val_loss: 1.2899 - val_accuracy: 0.8207
# Epoch 84/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0136 - accuracy: 0.9954 - val_loss: 1.3071 - val_accuracy: 0.8159
# Epoch 85/100
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0161 - accuracy: 0.9943 - val_loss: 1.3498 - val_accuracy: 0.8155
# Epoch 86/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0155 - accuracy: 0.9948 - val_loss: 1.3122 - val_accuracy: 0.8141
# Epoch 87/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0179 - accuracy: 0.9939 - val_loss: 1.3817 - val_accuracy: 0.8149
# Epoch 88/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0184 - accuracy: 0.9940 - val_loss: 1.3345 - val_accuracy: 0.8174
# Epoch 89/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0152 - accuracy: 0.9945 - val_loss: 1.2585 - val_accuracy: 0.8251
# Epoch 90/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 1.2529 - val_accuracy: 0.8241
# Epoch 91/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 1.3287 - val_accuracy: 0.8193
# Epoch 92/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0159 - accuracy: 0.9945 - val_loss: 1.3739 - val_accuracy: 0.8157
# Epoch 93/100
# 391/391 [==============================] - 14s 37ms/step - loss: 0.0169 - accuracy: 0.9939 - val_loss: 1.2894 - val_accuracy: 0.8202
# Epoch 94/100
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0141 - accuracy: 0.9951 - val_loss: 1.3575 - val_accuracy: 0.8200
# Epoch 95/100
# 391/391 [==============================] - 15s 39ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 1.3367 - val_accuracy: 0.8218
# Epoch 96/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 1.3617 - val_accuracy: 0.8170
# Epoch 97/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0177 - accuracy: 0.9939 - val_loss: 1.4091 - val_accuracy: 0.8149
# Epoch 98/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 1.3683 - val_accuracy: 0.8202
# Epoch 99/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 1.3303 - val_accuracy: 0.8243
# Epoch 100/100
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 1.3802 - val_accuracy: 0.8166

# %%
model.save("model3.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.style.use("ggplot")
fig =plt.figure()
plt.plot(np.arange(0, 100), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, 100), history.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()
image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'Los.svg'

fig.savefig(image_name, format=image_format, dpi=1200)

# %%
plt.style.use("ggplot")
fig2=plt.figure()
plt.plot(np.arange(0, 100), history.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0, 100), history.history["val_accuracy"], label="val_accuracy")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Acc")
plt.legend()
plt.show()
image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'Accuracy.svg'

fig2.savefig(image_name, format=image_format, dpi=1200)
